# %% [markdown]
# # Métodos de Integración numérica
# ### Luis Daniel Amador Islas

# %% [markdown]
# ## 1. Regla del Trapecio.
#
# El archivo $\texttt{velocidades.txt}$ (adjunto), contiene dos columnas de números, la primera representa el tiempo $t$ en segundos y la segunda la $x$-velocidad en metros por segundo de una partícula, medida una vez por segundo desde el tiempo $t = 0$ hasta $t = 100$.
# Las primeras líneas se ven asi:
#
#
# 0  0
#
# 1  0.069478
#
# 2  0.137694
#
# 3  0.204332
#
# 4  0.269083
#
# 5  0.331656
#
#
# Escribe un programa para hacer lo siguiente:

# %% [markdown]
# _a)_ Lee los datos y, usando la **regla del trapecio**, calcula a partir de ellos la distancia aproximada recorrida por la partícula en la dirección $x$ como una función del tiempo.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Leemos los datos del archivo
datos = np.loadtxt("velocidades.txt")
t = datos[:, 0]
v = datos[:, 1]

# Mostramos los primeros datos para verificar
print("Dato en 4 segundos:")
for i in range(5):
    print(f"Tiempo: {t[i]} s, Velocidad: {v[i]} m/s")

# Calculamos la distancia usando la regla del trapecio
d = np.zeros(len(t))
for i in range(1, len(t)):
    dt = t[i] - t[i-1] 
    area = dt * (v[i] + v[i-1]) / 2
    d[i] = d[i-1] + area

print(f"Distancia total recorrida: {d[-1]:.2f} metros")
# Out:
# Dato en 4 segundos:
# Tiempo: 0.0 s, Velocidad: 0.0 m/s
# Tiempo: 1.0 s, Velocidad: 0.069478 m/s
# Tiempo: 2.0 s, Velocidad: 0.137694 m/s
# Tiempo: 3.0 s, Velocidad: 0.204332 m/s
# Tiempo: 4.0 s, Velocidad: 0.269083 m/s
# Distancia total recorrida: 8.22 metros

# %% [markdown]
# _b)_ Extiende tu programa para hacer una gráfica que muestre, en el mismo gráfico, tanto la curva de velocidad original como la distancia recorrida como una función del tiempo.

# %%
#Creamos la gráfica
plt.figure(figsize=(12, 6))

# Crear la gráfica de velocidad
plt.plot(t, v, '#A020F0', linewidth=2, label='Velocidad')
plt.xlabel('Tiempo (s)')
plt.ylabel('Velocidad (m/s)', color='#A020F0')
plt.tick_params(axis='y', labelcolor='#A020F0')
plt.grid(True)

# Crear un segundo eje Y para la distancia
plt.twinx()
plt.plot(t, d, 'r-', linewidth=2, label='Distancia')
plt.ylabel('Distancia (m)', color='r')
plt.tick_params(axis='y', labelcolor='r')

plt.title('Velocidad en funcion Tiempo')
plt.show()

# %%
# Ejercicio 1b
plt.figure(figsize=(10, 5))
plt.plot(t, v, '#A020F0', linewidth=2, label='Velocidad')
plt.plot(t, d, 'r', label="Distancia recorrida")
plt.xlabel("Tiempo (s)")
plt.ylabel("Magnitud")
plt.title("Velocidad y distancia recorrida vs tiempo")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. El límite de difracción de un telescopio.
# Nuestra capacidad para resolver detalles en observaciones astronómicas está limitada por la difraccinón de la luz en nuestros telescopios. La luz de las estrellas puede considerarse efectivamente como si proviniera de una fuente puntual en el infinito. Cuando dicha luz, con una longitud de onda $\lambda$, pasa a través de la apertura circular de un telescopio (que supondremos que tiene un radio unitario) y es enfocada por el telescopio en el plano focal, no produce un solo punto, sino un patrón de difracción circular que consta de un punto central rodeado por una serie de anillos concéntricos.
# La intensidad de la luz en este patrón de difraccinón está dada por:
#
# $$ I(r) = \left(\frac{J_1(kr)}{kr}\right)^2, $$
#
# donde $r$ es la distancia en el plano focal desde el centro del patrón de difracción, $k = 2\pi/\lambda$ y $J_1(x)$ es una función de Bessel, Las funciones de Bessel $J_m(x)$ están dadas por:
#
# $$J_m(x) = \frac{1}{\pi} \int_0^{\pi} \cos(m\theta - x \sin(\theta)) \text{d}\theta,$$
#
# donde $m$ es un entero no negativo y $x \geq 0$

# %% [markdown]
# _a)_ Escribe una función $\texttt{J(m, x)}$ que calcule el calor de $J_m(x)$ usando la regla de Simpson con $N = 1000$ puntos. Utiliza dicha función en un programa para graficar, en un solo gráfico, las funciones de Bessel $J_0, J_1 y J_2$ como una función de $x$ (de $x = 0 $ a $x = 20$)

# %%
import numpy as np
import matplotlib.pyplot as plt

#Regla de Simpson (versión de clase)
def simpson(f, a, b, N):
    if N % 2 != 0:
        N += 1  # Asegurar que N sea par

    h = (b - a) / N
    x = np.linspace(a, b, N + 1)

    suma_par = 0
    suma_impar = 0

    for i in range(1, N//2 + 1):
        x_par = x[2*i]
        suma_par += 2 * f(x_par)

    for i in range(1, N//2 + 1):
        x_impar = x[2*i - 1]
        suma_impar += 4 * f(x_impar)

    integral = (h/3) * (suma_par + suma_impar + f(x[0]) - f(x[N]))
    return integral

#Función de Bessel J_m(x)
def J(m, x, N=1000):
    a = 0
    b = np.pi
    f = lambda theta: np.cos(m * theta - x * np.sin(theta))
    return (1 / np.pi) * simpson(f, a, b, N)

#Cálculo para m = 0, 1, 2
x_vals = np.linspace(0, 20, 300)
J0 = [J(0, x) for x in x_vals]
J1 = [J(1, x) for x in x_vals]
J2 = [J(2, x) for x in x_vals]

plt.figure(figsize=(10, 6))
plt.plot(x_vals, J0, "#000000" , label="J0(x)")
plt.plot(x_vals, J1, "#5ECC74", label="J1(x)")
plt.plot(x_vals, J2, "#960ACC", label="J2(x)")
plt.title("Funciones de Bessel J0, J1 y J2 con la regla de Simpson")
plt.xlabel("x")
plt.ylabel("Jm(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# _b)_ Compara tus resultados con los proporcionados con la biblioteca de $\texttt{scipy}$ que implementa la regla de Simpson.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jv

def simpson(f, a, b, N):
    if N % 2 != 0:
        N += 1
    h = (b - a) / N
    x = np.linspace(a, b, N + 1)

    suma_par = 0
    suma_impar = 0

    for i in range(1, N//2 + 1):
        x_par = x[2*i]
        suma_par += 2 * f(x_par)

    for i in range(1, N//2 + 1):
        x_impar = x[2*i - 1]
        suma_impar += 4 * f(x_impar)

    integral = (h/3) * (suma_par + suma_impar + f(x[0]) - f(x[N]))
    return integral

def J(m, x, N=1000):
    a = 0
    b = np.pi
    f = lambda theta: np.cos(m * theta - x * np.sin(theta))
    return (1 / np.pi) * simpson(f, a, b, N)

x_vals = np.linspace(0, 20, 300)

# Comparacion mi funcion y las de scipy
J1_mia = [J(1, x) for x in x_vals]
J1_scipy = [jv(1, x) for x in x_vals]

plt.figure(figsize=(10, 6))
plt.plot(x_vals, J1_mia, '#320345', label='J1(x) con Simpson (propia)')
plt.plot(x_vals, J1_scipy, 'y--', label='J1(x) con scipy.special.jv')
plt.xlabel("x")
plt.ylabel("J1(x)")
plt.title("Comparación entre J1(x) calculada y scipy.special.jv")
plt.legend()
plt.grid(True)
plt.show()

diferencia = np.mean(np.abs(np.array(J1_mia) - np.array(J1_scipy)))
print(f"Diferencia promedio entre métodos: {diferencia:.3e}")
# Out:
# Diferencia promedio entre métodos: 1.454e-16

# %% [markdown]
# _c)_ Escribe un segundo programa que haga una fráfica de densidad ($\texttt{density plot}$) de la intensidad del patrón de difracción circular de una fuente de luz puntual con $\lambda = 500$nm, en una región cuadrada del plano focal, usando la fórmula dada anteriormente. Su imagen debe cubrir valores de $r$ desde cero hasta aproximadamente 1$\mu$m.
#
# Hint 1: Puede resultarte útil saber que $lím_{x\to 0} \frac{J_1}{x} = \frac{1}{2}$.
#
# Hint 2: EL punto central en el patrón de difracción es tan brillante que pede resultar difícil ver los anillos que lo rodean en la pantalla de la comptadora; para solucionar ésta situación puedes usar el esquema "$\texttt{hot}$" funciona bien. Tu gráfica debería verse algo así:

# %%
from IPython.display import Image
Image(filename= 'C:/Users/DANROK/Fisica_Computacional/Repositorio_Fisica_Computacional/1_ProgramacionPython/Diagrama_T4_E2.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import j1

# Longitud de onda en metros
lamb = 500e-9
k = 2 * np.pi / lamb

# Región del plano focal (en metros)
r_max = 1e-6
N = 400
x = np.linspace(-r_max, r_max, N)
y = np.linspace(-r_max, r_max, N)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)

kr = k * R
kr[kr == 0] = 1e-20

# Intensidad del patrón de difracción
I = (j1(kr) / kr)**2
#Otros cmap con los que se ve muy claro viridis, cividis, pink, seismic, RdBu, PRGn, BrBG, twilight_shifted, hsv, jet, "gist_ncar" este ultimo casi igual de bien
plt.figure(figsize=(6, 6))
plt.imshow(I, cmap="nipy_spectral", extent=[-1, 1, -1, 1])
plt.title('Patrón de difracción circular (λ = 500 nm)')
plt.xlabel('x (μm)')
plt.ylabel('y (μm)')
plt.colorbar(label='Intensidad relativa')
plt.show()

# %% [markdown]
# ## 3. Periodo de un oscilador anarmónico.
#
# El oscilador armónico simple aparece en muchos lugares. Su comportamiento puede estudiarse fácilmente mediante métodos analtíticos y tiene la importante propiedad de que su período de oscilación es constante inependiente de su amplitud, lo que lo hace útil por ejemplo, para medir el tiepo en relojes. Sin embargo, en física también nos encontramos con frecuencia con **osciladores anarmónicos**, cuyo período varía con la amplitud y cuyo comportamiento no suele calcularse analíticamente.
#
# En general, un oscilador clásico puede considerarse como una partícula en un pozo de potencial cóncavo. Al ser perturbada, la partícula se balanceará en el pozo:

# %%
from IPython.display import Image
Image(filename= 'C:/Users/DANROK/Fisica_Computacional/Repositorio_Fisica_Computacional/1_ProgramacionPython/Diagrama_T4_E3.jpg')

# %% [markdown]
# El _oscilador armónico_ corresponde a un potencial cuadrático $V(x) \alpha x^2$. Cualquier otra forma daría como reultado un _oscilador anarmónico_.(Por lo tanto, existen muchos tipos diferentes de osciladores anarmónicos, dependiendo de la forma exacta del potencial).
#
# Una forma de calcular el movimiento de un oscilador es escribir la ecuacion de conservación de la energía en el sistema. Si la partícula tiene masa $m$ y posición $x$, entonces la energía total es igual a la suma de las energías cinética y potencial, por lo tanto:
#
# $$E = \frac{1}{2}m (\frac{dx}{dt})^2 + V(x) $$
#
# Dado que la energía debe ser constante en el tiempo, esta cuación es, en efecto, una ecuación diferencial (no lineal) que relaciona 4X$ y Xt$.
#
# Supongamos que el potencial $V(x)$ es simétrico respecto a $x = 0$ y pongamos en movimiento nuestro oscilador anarmónico con amplitu $a$. Es decir, en $t = 0$ lo liberamos dede el reposo en la posición $x = a$ y oscila de vuelta hacia el origen. Entonces, en $t = 0$, tenemos $\frac{dx}{dt} = 0$, y la ecuación anterior se convierte en $E = V(a)$, lo que nos da la energía total de la partícula en términos de la amplitud.
#
# _a)_ Cuando la partícula alcanza el origen ($x = 0$) por primera vez, se ha recorrido un cuarto del periodo del oscilador. Reordena la ecuaciónde la energía total $E$ para despejar $\frac{dx}{dt}$ y luego integra con respecto a $t$ desde 0 hasta $\frac{1}{4} T$, para demostrar que el periodo $T$ del oscilador está dado por:
#
# $$T = \sqrt{8m} \int_0^a \frac{dx}{\sqrt{V(a) - V(x)}}$$

# %% [markdown]
# Partimos de la conservación de la energía:
#
# $$
# E = \frac{1}{2}m\left(\frac{dx}{dt}\right)^2 + V(x)
# $$
#
# En $ t = 0 $, tenemos $ x = a $ y $ \frac{dx}{dt} = 0 $, por lo tanto:
#
# $$
# E = V(a)
# $$
#
# Sustituyendo en la ecuación de energía:
#
# $$
# V(a) = \frac{1}{2}m\left(\frac{dx}{dt}\right)^2 + V(x)
# $$
#
# Despejamos $ \frac{dx}{dt} $:
#
# $$
# \frac{1}{2}m\left(\frac{dx}{dt}\right)^2 = V(a) - V(x)
# $$
#
# $$
# \left(\frac{dx}{dt}\right)^2 = \frac{2}{m}[V(a) - V(x)]
# $$
#
# $$
# \frac{dx}{dt} = -\sqrt{\frac{2}{m}[V(a) - V(x)]}
# $$
#
# El signo negativo indica que la partícula se mueve hacia el origen ($ x $ decreciente).
#
# Separamos variables:
#
# $$
# dt = -\frac{dx}{\sqrt{\frac{2}{m}[V(a) - V(x)]}} = -\sqrt{\frac{m}{2}} \frac{dx}{\sqrt{V(a) - V(x)}}
# $$
#
# Integramos desde $ t = 0 $ hasta $t = \frac{T}{4}$, que corresponde a $x = a$ hasta $x = 0$:
#
# $$
# \int_0^{T/4} dt = -\sqrt{\frac{m}{2}} \int_a^0 \frac{dx}{\sqrt{V(a) - V(x)}}
# $$
#
# $$
# \frac{T}{4} = -\sqrt{\frac{m}{2}} \left[ -\int_0^a \frac{dx}{\sqrt{V(a) - V(x)}} \right]
# $$
#
# $$
# \frac{T}{4} = \sqrt{\frac{m}{2}} \int_0^a \frac{dx}{\sqrt{V(a) - V(x)}}
# $$
#
# Multiplicando ambos lados por 4:
#
# $$
# T = \sqrt{8m} \int_0^a \frac{dx}{\sqrt{V(a) - V(x)}}
# $$

# %% [markdown]
# _b)_ Ahora, supongamos que el potencial es $V(x) = x^4$ y la masa de la partícula es $m = 1$. Escribe una función de $\texttt{Python}$ que calcule el periodo del oscilador para la amplitud dada $a$ utilizando la **Cuadratura Gaussiana** con $N = 20$ puntos. Luego, usa la función para graficar el periodo para amplitudes que van desde $a = 0$ hasta $a = 2$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.legendre import leggauss

# Potencial y parametros
V = lambda x: x**4
m = 1.0

# Gauss-Legendre para intervalo [0, a]
def periodo_gauss_legendre(a, Vfunc, m=1.0, N=20):
    if a == 0:
        return np.inf
    # puntos y pesos en [-1,1]
    xs, ws = leggauss(N)
    t = xs
    x_mapped = 0.5 * a * (t + 1.0)
    integrand_vals = 1.0 / np.sqrt(np.maximum(Vfunc(a) - Vfunc(x_mapped), 1e-20))
    I = np.sum(ws * integrand_vals) * (0.5 * a)
    T = np.sqrt(8.0 * m) * I
    return T

a_vals = np.linspace(0.01, 2.0, 200)
T_vals = np.array([periodo_gauss_legendre(a, V, m=1.0, N=20) for a in a_vals])

plt.figure(figsize=(8,5))
plt.plot(a_vals, T_vals, '-k')
plt.xlabel("Amplitud a")
plt.ylabel("Periodo T(a)")
plt.title("Periodo del oscilador con V(x)=x^4 (Gauss-Legendre N=20)")
plt.grid(True)
plt.ylim(bottom=0)
plt.show()

for a_sample in [0.01, 0.05, 0.1, 0.5, 1.0, 2.0]:
    print(f"a = {a_sample: .3f}  ->  T = {periodo_gauss_legendre(a_sample, V, m=1.0, N=20): .6f}")
# Out:
# a =  0.010  ->  T =  364.809408
# a =  0.050  ->  T =  72.961882
# a =  0.100  ->  T =  36.480941
# a =  0.500  ->  T =  7.296188
# a =  1.000  ->  T =  3.648094
# a =  2.000  ->  T =  1.824047

# %% [markdown]
# _c)_ Deberías observar que el oscilador se acelera a medida que aumenta la amplitud, aunque la particula tiene que recorer más distancia para alcanzar una amplitud mayor. Y deberías observar que el período diverge a medida que la amplitud se acerca a cero.¿Cómo explicas estos resultados?

# %% [markdown]
# Cuando la amplitud $ a $ tiende a cero, el período $ T $ diverge porque el integrando en la expresión del período,
#
# $$
# \frac{1}{\sqrt{V(a) - V(x)}} = \frac{1}{\sqrt{a^4 - x^4}},
# $$
#
# presenta una singularidad más pronunciada a medida que $ a $ disminuye. Para $ x $ cercano a $ a $ podemos aproximar $ a^4 - x^4 \approx 4a^3(a - x) $ de modo que el integrando se comporta como $ (a - x)^{-1/2} $ Aunque esta singularidad es integrable para $ a $ fijo, la integral resultante escala de manera que, al multiplicarse por $ \sqrt{8m} $ el período diverge cuando $ a \to 0 $ Esto refleja que, a amplitudes muy pequeñas, la partícula tarda cada vez más en completar una oscilación debido a que la fuerza restauradora se vuelve extremadamente débil cerca del punto de retorno.
#
# Por otro lado, al aumentar la amplitud $ a $ el período disminuye porque, aunque la distancia total recorrida por la partícula es mayor, la fuerza restauradora $ F = -dV/dx = -4x^3 $ crece rápidamente con $ x $ Esta dependencia cúbica hace que la aceleración sea significativamente mayor a amplitudes altas, aumentando así la velocidad media de la partícula. Este incremento en la velocidad compensa con creces la mayor distancia recorrida, resultando en una disminución neta del período. Este comportamiento contrasta con el oscilador armónico, donde la fuerza crece linealmente con $ x $, y el aumento de la distancia se compensa exactamente con el aumento de velocidad, dando lugar a un período independiente de la amplitud.

# %% [markdown]
# ## 4. La constante de Stefan-Boltzmann.
#
# La teoría de PLanck de la radiación térmica nos dice que en el intervalo de frecuencia (angular) de $\omega$ a $\omega + d\omega$, un cuerpo negro de área unitaria irradia electromagnéticamente una cantidad de energía térmica por segundo igual a $I(\omega)d\omega$, donde
#
# $$I(\omega) = \frac{\hbar}{4\pi^2c^2} \frac{\omega^3}{(e^{\hbar\omega / k_B T} - 1)}$$
#
# _a)_ Demuestra que la energía total por unidad de área radiada por un cuerpo negro es:
#
# $$W = \frac{k_B^4 T^4}{4\pi^2c^2\hbar^3} \int_0^\infty \frac{x^3}{e^x - 1} dx-$$

# %% [markdown]
# Partimos de la expresión dada para la intensidad espectral:
#
# $$
# I(\omega) = \frac{\hbar}{4\pi^2 c^2} \frac{\omega^3}{e^{\hbar\omega / k_B T} - 1}
# $$
#
# La energía total por unidad de área radiada por un cuerpo negro es la integral sobre todas las frecuencias:
#
# $$
# W = \int_0^\infty I(\omega) \, d\omega = \frac{\hbar}{4\pi^2 c^2} \int_0^\infty \frac{\omega^3}{e^{\hbar\omega / k_B T} - 1} \, d\omega
# $$
#
# Hacemos el cambio de variable:
#
# $$
# x = \frac{\hbar\omega}{k_B T} \quad \Rightarrow \quad \omega = \frac{k_B T}{\hbar}x
# $$
#
# $$
# d\omega = \frac{k_B T}{\hbar} dx
# $$
#
# Sustituimos en la integral:
#
# $$
# W = \frac{\hbar}{4\pi^2 c^2} \int_0^\infty \frac{\left(\frac{k_B T}{\hbar}x\right)^3}{e^x - 1} \cdot \frac{k_B T}{\hbar} dx
# $$
#
# Simplificamos:
#
# $$
# W = \frac{\hbar}{4\pi^2 c^2} \cdot \frac{k_B^4 T^4}{\hbar^4} \int_0^\infty \frac{x^3}{e^x - 1} dx
# $$
#
# $$
# W = \frac{k_B^4 T^4}{4\pi^2 c^2 \hbar^3} \int_0^\infty \frac{x^3}{e^x - 1} dx
# $$

# %% [markdown]
# _b)_ Escribe un programa para evaluar la integral de esta expresíon, usando la _regla del trapecio_, la _regla de Simpson_ y la _Cuadratura Gaussiana_; explica la precision de cada respuesta.

# %%
import numpy as np
from numpy.polynomial.legendre import leggauss
from numpy.polynomial.laguerre import laggauss

def f(x):
    """Función a integrar: x³/(eˣ - 1)"""
    mask = x < 1e-6
    result = np.zeros_like(x)
    result[mask] = x[mask]**2  # Límite: x³/(eˣ - 1) ≈ x² cuando x → 0
    result[~mask] = x[~mask]**3 / (np.exp(x[~mask]) - 1)
    return result

#REGLA DEL TRAPECIO
def trapecio(f, a, b, N):
    x = np.linspace(a, b, N+1)
    y = f(x)
    h = (b - a) / N
    return h * (0.5*y[0] + 0.5*y[-1] + np.sum(y[1:-1]))

#REGLA DE SIMPSON
def simpson(f, a, b, N):
    if N % 2 == 1:
        N += 1
    h = (b - a) / N
    x = np.linspace(a, b, N+1)
    y = f(x)
    return (h/3) * (y[0] + y[-1] + 4*np.sum(y[1:-1:2]) + 2*np.sum(y[2:-1:2]))

#CUADRATURA GAUSSIANA
def gauss_legendre(f, a, b, N):
    xs, ws = leggauss(N)
    # Mapeo de [-1,1] a [a,b]
    x_mapped = 0.5*(b - a)*xs + 0.5*(b + a)
    return 0.5*(b - a) * np.sum(ws * f(x_mapped))

def gauss_laguerre(f, N):
    xs, ws = laggauss(N)
    # Gauss-Laguerre: ∫₀^∞ e^{-x} g(x) dx ≈ Σ wᵢ g(xᵢ)
    # Para nuestra f(x) = x³/(eˣ - 1) = e^{-x} [x³/(1 - e^{-x})]
    g = lambda x: x**3 / (1 - np.exp(-x))
    return np.sum(ws * g(xs))

# Parámetros de integración
B = 20.0  # Límite superior
N_trap = 10000
N_simp = 1000
N_gl = 50
N_gauss_leg = 50

I_trap = trapecio(f, 0, B, N_trap)
I_simp = simpson(f, 0, B, N_simp)
I_gauss_leg = gauss_legendre(f, 0, B, N_gauss_leg)
I_gauss_lag = gauss_laguerre(f, N_gl)

I_exacto = np.pi**4 / 15

print("MÉTODO                 VALOR                  ERROR")
print(f"Trapecio (N={N_trap})    {I_trap:.12f}    {abs(I_trap - I_exacto):.2e}")
print(f"Simpson (N={N_simp})     {I_simp:.12f}    {abs(I_simp - I_exacto):.2e}")
print(f"Gauss-Legendre (N={N_gauss_leg}) {I_gauss_leg:.12f}    {abs(I_gauss_leg - I_exacto):.2e}")
print(f"Gauss-Laguerre (N={N_gl}) {I_gauss_lag:.12f}    {abs(I_gauss_lag - I_exacto):.2e}")
print(f"Valor exacto (π⁴/15)    {I_exacto:.12f}")
# Out:
# MÉTODO                 VALOR                  ERROR
# Trapecio (N=10000)    6.493920179943    1.92e-05
# Simpson (N=1000)     6.493920182615    1.92e-05
# Gauss-Legendre (N=50) 6.493920179948    1.92e-05
# Gauss-Laguerre (N=50) 6.493939402268    1.05e-12
# Valor exacto (π⁴/15)    6.493939402267

# %% [markdown]
# _c)_ Inlcuso antes de que Planck presentara su teoría de la radiación térmica a principios del siglo XX, se sabía que la energía total $W$ emitida por un cuerpo negro por unidad de área por segundo seguía la ley de Stefan: $W = \sigma T^4$, donde $\sigma$ es la constante de Stefan-Boltzmann. Usa el valor de la integral anterior para calcular la constante de Stefan-Boltzmann (en unidades del SI) con tres cirfras significativas. Compara tu resultado con el valor conocido; deberías obtener una buena concordancia.

# %%
import numpy as np
from scipy import constants as const
from numpy.polynomial.laguerre import laggauss

def calcular_integral(N=50):
    x, w = laggauss(N)
    g = x**3 / (1 - np.exp(-x))
    return np.sum(w * g)

I = calcular_integral()

# Constantes
k_B = const.k
hbar = const.hbar  
c = const.c

sigma = (k_B**4 / (4 * np.pi**2 * c**2 * hbar**3)) * I

# Valor de referencia
sigma_ref = const.Stefan_Boltzmann

print(f"Integral calculada: {I:.8f}")
print(f"Sigma calculada:    {sigma:.4e} W/m²K⁴")
print(f"Sigma referencia:   {sigma_ref:.4e} W/m²K⁴")

# Verificamos a 3 cifras
sigma_3 = float(f"{sigma:.3e}")
sigma_ref_3 = float(f"{sigma_ref:.3e}")

if abs(sigma_3 - sigma_ref_3) < 1e-11:
    print("✓")
else:
    print(f"\nA 3 cifras significativas:")
    print(f"Calculado:  {sigma_3:.3e} W/m²K⁴")
    print(f"Referencia: {sigma_ref_3:.3e} W/m²K⁴")
    print("✗ Margen de error")
# Out:
# Integral calculada: 6.49393940
# Sigma calculada:    5.6704e-08 W/m²K⁴
# Sigma referencia:   5.6704e-08 W/m²K⁴
# ✓
